# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Replace 'file_path.csv' with the path to your CSV file
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
for i in df.columns:
   print("Description of column: ", i)
   print(df[i].describe())
# Out:
# Description of column:  Age
# count    918.000000
# mean      53.510893
# std        9.432617
# min       28.000000
# 25%       47.000000
# 50%       54.000000
# 75%       60.000000
# max       77.000000
# Name: Age, dtype: float64
# Description of column:  Sex
# count     918
# unique      2
# top         M
# freq      725
# Name: Sex, dtype: object
# Description of column:  ChestPainType
# count     918
# unique      4
# top       ASY
# freq      496
# Name: ChestPainType, dtype: object
# Description of column:  RestingBP
# count    918.000000
# mean     132.396514
# std       18.514154
# min        0.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: RestingBP, dtype: float64
# Description of column:  Cholesterol
# count    918.000000
# mean     198.799564
# std      109.384145
# min        0.000000
# 25%      173.250000
# 50%      223.000000
# 75%      267.000000
# max      603.000000
# Name: Cholesterol, dtype: float64
# Description of column:  FastingBS
# count    918.000000
# mean       0.233115
# std        0.423046
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: FastingBS, dtype: float64
# Description of column:  RestingECG
# count        918
# unique         3
# top       Normal
# freq         552
# Name: RestingECG, dtype: object
# Description of column:  MaxHR
# count    918.000000
# mean     136.809368
# std       25.460334
# min       60.000000
# 25%      120.000000
# 50%      138.000000
# 75%      156.000000
# max      202.000000
# Name: MaxHR, dtype: float64
# Description of column:  ExerciseAngina
# count     918
# unique      2
# top         N
# freq      547
# Name: ExerciseAngina, dtype: object
# Description of column:  Oldpeak
# count    918.000000
# mean       0.887364
# std        1.066570
# min       -2.600000
# 25%        0.000000
# 50%        0.600000
# 75%        1.500000
# max        6.200000
# Name: Oldpeak, dtype: float64
# Description of column:  ST_Slope
# count      918
# unique       3
# top       Flat
# freq       460
# Name: ST_Slope, dtype: object
# Description of column:  HeartDisease
# count    918.000000
# mean       0.553377
# std        0.497414
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: HeartDisease, dtype: float64

# %%
# histogram to visualize the distribution of values for each column
for i in df.columns:
   print("Histogram of column: ", i)
   df[i].hist()
   plt.show()

# %%
df.plot(kind='scatter', x='Age', y='MaxHR')
plt.show()

# %%
sns.boxplot(y=df['MaxHR'])
plt.show()

# %%
# Calculate the correlation matrix for numeric columns only
corr = df.select_dtypes(include=['float64', 'int64']).corr()

# Now let's use this correlation matrix to generate a heatmap:
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Problem definition: Prediction of heart disease

# %% [markdown]
# Initial feature engineering

# %%
# Replace empty strings with NaN so they can be handled by dropna
df.replace('', np.nan, inplace=True)

# %% [markdown]
# Feature Extraction -- Set targets

# %%
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: HeartDisease, dtype: int64
# count    918.000000
# mean       0.553377
# std        0.497414
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: HeartDisease, dtype: float64
